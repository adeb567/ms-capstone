# %%
# %cd '/content/drive/MyDrive/4th_Semester/Capstone/yolact'
# Out:
# /content/drive/MyDrive/4th_Semester/Capstone/yolact

# %%
# !python eval.py --trained_model=weights/trash_base.pth --output_coco_json --config=trash_base_config --dataset=trash_dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
# loading annotations into memory...
# Done (t=0.60s)
# creating index...
# index created!
# /usr/local/lib/python3.10/dist-packages/torch/jit/_recursive.py:313: UserWarning: 'lat_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_recursive.py:313: UserWarning: 'downsample_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn(
# ...

# %%
# !python eval.py --trained_model=weights/trash_base.pth --score_threshold=0.15 --config=trash_base_config --images='/content/drive/MyDrive/4th_Semester/Capstone/Original_Size/val_enhanced':'/content/drive/MyDrive/4th_Semester/Capstone/Original_Size/val_enhanced_p'
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
# /usr/local/lib/python3.10/dist-packages/torch/jit/_recursive.py:313: UserWarning: 'downsample_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_recursive.py:313: UserWarning: 'pred_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_recursive.py:313: UserWarning: 'lat_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn(
# ...
